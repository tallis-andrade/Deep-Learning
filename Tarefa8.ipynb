# %% [markdown]
# <a href="https://colab.research.google.com/github/tallis-andrade/Deep-Learning/blob/main/Tarefa8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)

# !pip install -q tensorflow-datasets
# Out:
# 2.9.2

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("ag_news_subset", with_info=True, as_supervised=True)
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)
# Out:
# Downloading and preparing dataset 11.24 MiB (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to ~/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/ag_news_subset/1.0.0.incompleteAZEPXU/ag_news_subset-train.tfrecord*...:   0%|…
# Generating test examples...:   0%|          | 0/7600 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/ag_news_subset/1.0.0.incompleteAZEPXU/ag_news_subset-test.tfrecord*...:   0%| …
# Dataset ag_news_subset downloaded and prepared to ~/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = ""


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? b'reuters major league baseball monday announced a decision on the appeal filed by chicago cubs pitcher kerry wood regarding a suspension stemming from an incident earlier this season '
# b'Reuters - Major League Baseball\\Monday announced a decision on the appeal filed by Chicago Cubs\\pitcher Kerry Wood regarding a suspension stemming from an\\incident earlier this season.'

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])
#model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
num_epochs = 10
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 120, 16)           160000
#
#  bidirectional (Bidirectiona  (None, 64)               9600
#  l)
#
#  dense (Dense)               (None, 6)                 390
#
#  dense_1 (Dense)             (None, 4)                 28
#
# =================================================================
# Total params: 170,018
# Trainable params: 170,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3750/3750 [==============================] - 120s 31ms/step - loss: 0.5058 - accuracy: 0.8028 - val_loss: 0.3281 - val_accuracy: 0.8930
# Epoch 2/10
# 3750/3750 [==============================] - 117s 31ms/step - loss: 0.2747 - accuracy: 0.9086 - val_loss: 0.2935 - val_accuracy: 0.8986
# Epoch 3/10
# 3750/3750 [==============================] - 117s 31ms/step - loss: 0.2327 - accuracy: 0.9218 - val_loss: 0.2991 - val_accuracy: 0.8988
# Epoch 4/10
# 3750/3750 [==============================] - 118s 31ms/step - loss: 0.2062 - accuracy: 0.9306 - val_loss: 0.3015 - val_accuracy: 0.8979
# Epoch 5/10
# 3750/3750 [==============================] - 118s 31ms/step - loss: 0.1831 - accuracy: 0.9381 - val_loss: 0.2997 - val_accuracy: 0.9026
# Epoch 6/10
# 3750/3750 [==============================] - 117s 31ms/step - loss: 0.1622 - accuracy: 0.9459 - val_loss: 0.3265 - val_accuracy: 0.8963
# Epoch 7/10
# 3750/3750 [==============================] - 118s 32ms/step - loss: 0.1436 - accuracy: 0.9520 - val_loss: 0.3655 - val_accuracy: 0.8958
# Epoch 8/10
# 3750/3750 [==============================] - 120s 32ms/step - loss: 0.1261 - accuracy: 0.9572 - val_loss: 0.3482 - val_accuracy: 0.8959
# Epoch 9/10
# 3750/3750 [==============================] - 120s 32ms/step - loss: 0.1105 - accuracy: 0.9631 - val_loss: 0.3798 - val_accuracy: 0.8903
# Epoch 10/10
# 3750/3750 [==============================] - 121s 32ms/step - loss: 0.0972 - accuracy: 0.9676 - val_loss: 0.4012 - val_accuracy: 0.8920

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
# Model Definition with LSTM
model2 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])
model2.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model2.summary()
num_epochs = 10
history = model2.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 120, 16)           160000
#
#  bidirectional_1 (Bidirectio  (None, 64)               12544
#  nal)
#
#  dense_2 (Dense)             (None, 6)                 390
#
#  dense_3 (Dense)             (None, 4)                 28
#
# =================================================================
# Total params: 172,962
# Trainable params: 172,962
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3750/3750 [==============================] - 134s 35ms/step - loss: 0.4761 - accuracy: 0.8189 - val_loss: 0.3046 - val_accuracy: 0.8989
# Epoch 2/10
# 3750/3750 [==============================] - 132s 35ms/step - loss: 0.2562 - accuracy: 0.9151 - val_loss: 0.3006 - val_accuracy: 0.8978
# Epoch 3/10
# 3750/3750 [==============================] - 132s 35ms/step - loss: 0.2191 - accuracy: 0.9261 - val_loss: 0.2978 - val_accuracy: 0.8986
# Epoch 4/10
# 3750/3750 [==============================] - 133s 35ms/step - loss: 0.1919 - accuracy: 0.9344 - val_loss: 0.2948 - val_accuracy: 0.9042
# Epoch 5/10
# 3750/3750 [==============================] - 132s 35ms/step - loss: 0.1691 - accuracy: 0.9418 - val_loss: 0.3038 - val_accuracy: 0.9025
# Epoch 6/10
# 3750/3750 [==============================] - 133s 35ms/step - loss: 0.1480 - accuracy: 0.9488 - val_loss: 0.3326 - val_accuracy: 0.8989
# Epoch 7/10
# 3750/3750 [==============================] - 132s 35ms/step - loss: 0.1300 - accuracy: 0.9544 - val_loss: 0.3493 - val_accuracy: 0.8995
# Epoch 8/10
# 3750/3750 [==============================] - 140s 37ms/step - loss: 0.1139 - accuracy: 0.9605 - val_loss: 0.3781 - val_accuracy: 0.8938
# Epoch 9/10
# 3750/3750 [==============================] - 132s 35ms/step - loss: 0.1001 - accuracy: 0.9658 - val_loss: 0.4007 - val_accuracy: 0.8908
# Epoch 10/10
# 3750/3750 [==============================] - 132s 35ms/step - loss: 0.0876 - accuracy: 0.9699 - val_loss: 0.4009 - val_accuracy: 0.8920

# %%
# Model Definition with Conv1D
model3 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(4, activation='softmax')
])
model3.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model3.summary()
num_epochs = 10
history = model3.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 120, 16)           160000
#
#  conv1d (Conv1D)             (None, 116, 128)          10368
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 178,884
# Trainable params: 178,884
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3750/3750 [==============================] - 44s 12ms/step - loss: 0.4136 - accuracy: 0.8541 - val_loss: 0.2958 - val_accuracy: 0.9000
# Epoch 2/10
# 3750/3750 [==============================] - 31s 8ms/step - loss: 0.2589 - accuracy: 0.9150 - val_loss: 0.2847 - val_accuracy: 0.9018
# Epoch 3/10
# 3750/3750 [==============================] - 32s 9ms/step - loss: 0.2288 - accuracy: 0.9240 - val_loss: 0.2834 - val_accuracy: 0.9020
# Epoch 4/10
# 3750/3750 [==============================] - 31s 8ms/step - loss: 0.2072 - accuracy: 0.9296 - val_loss: 0.2993 - val_accuracy: 0.9017
# Epoch 5/10
# 3750/3750 [==============================] - 30s 8ms/step - loss: 0.1892 - accuracy: 0.9340 - val_loss: 0.3080 - val_accuracy: 0.8999
# Epoch 6/10
# 3750/3750 [==============================] - 31s 8ms/step - loss: 0.1719 - accuracy: 0.9381 - val_loss: 0.3393 - val_accuracy: 0.8979
# Epoch 7/10
# 3750/3750 [==============================] - 32s 9ms/step - loss: 0.1574 - accuracy: 0.9413 - val_loss: 0.3678 - val_accuracy: 0.8989
# Epoch 8/10
# 3750/3750 [==============================] - 31s 8ms/step - loss: 0.1441 - accuracy: 0.9450 - val_loss: 0.3825 - val_accuracy: 0.8957
# Epoch 9/10
# 3750/3750 [==============================] - 31s 8ms/step - loss: 0.1339 - accuracy: 0.9479 - val_loss: 0.4158 - val_accuracy: 0.8941
# Epoch 10/10
# 3750/3750 [==============================] - 31s 8ms/step - loss: 0.1236 - accuracy: 0.9502 - val_loss: 0.4474 - val_accuracy: 0.8972
